# %% [markdown]
# <a href="https://colab.research.google.com/github/EnverSkywalker/Pyhton.v360/blob/main/datasetanaliz(spotify).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/content/songs_normalize.csv")
df.info()
df.head()

# %%
#Dataseti düzenliyoruz(bazı columnları çıkarıtyoruz)
df2 = df.drop("explicit", axis=1)
df2.head()
# Out:
#            artist                    song  duration_ms  year  popularity  \
# 0  Britney Spears  Oops!...I Did It Again       211160  2000          77
# 1       blink-182    All The Small Things       167066  1999          79
# 2      Faith Hill                 Breathe       250546  1999          66
# 3        Bon Jovi            It's My Life       224493  2000          78
# 4          *NSYNC             Bye Bye Bye       200560  2000          65
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.751   0.834    1    -5.444     0       0.0437        0.3000
# 1         0.434   0.897    0    -4.918     1       0.0488        0.0103
# 2         0.529   0.496    7    -9.007     1       0.0290        0.1730
# 3         0.551   0.913    0    -4.063     0       0.0466        0.0263
# 4         0.614   0.928    8    -4.806     0       0.0516        0.0408
#
#    instrumentalness  liveness  valence    tempo         genre
# ...

# %%
df3 = df2.drop("key", axis=1)
df3.head()
# Out:
#            artist                    song  duration_ms  year  popularity  \
# 0  Britney Spears  Oops!...I Did It Again       211160  2000          77
# 1       blink-182    All The Small Things       167066  1999          79
# 2      Faith Hill                 Breathe       250546  1999          66
# 3        Bon Jovi            It's My Life       224493  2000          78
# 4          *NSYNC             Bye Bye Bye       200560  2000          65
#
#    danceability  energy  loudness  mode  speechiness  acousticness  \
# 0         0.751   0.834    -5.444     0       0.0437        0.3000
# 1         0.434   0.897    -4.918     1       0.0488        0.0103
# 2         0.529   0.496    -9.007     1       0.0290        0.1730
# 3         0.551   0.913    -4.063     0       0.0466        0.0263
# 4         0.614   0.928    -4.806     0       0.0516        0.0408
#
#    instrumentalness  liveness  valence    tempo         genre
# ...

# %%
df4 = df3.drop("mode", axis=1)
df4.head()
# Out:
#            artist                    song  duration_ms  year  popularity  \
# 0  Britney Spears  Oops!...I Did It Again       211160  2000          77
# 1       blink-182    All The Small Things       167066  1999          79
# 2      Faith Hill                 Breathe       250546  1999          66
# 3        Bon Jovi            It's My Life       224493  2000          78
# 4          *NSYNC             Bye Bye Bye       200560  2000          65
#
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.751   0.834    -5.444       0.0437        0.3000
# 1         0.434   0.897    -4.918       0.0488        0.0103
# 2         0.529   0.496    -9.007       0.0290        0.1730
# 3         0.551   0.913    -4.063       0.0466        0.0263
# 4         0.614   0.928    -4.806       0.0516        0.0408
#
#    instrumentalness  liveness  valence    tempo         genre
# 0          0.000018    0.3550    0.894   95.053           pop
# ...

# %%
df5 = df4.drop("instrumentalness", axis=1)
df5.head()
# Out:
#            artist                    song  duration_ms  year  popularity  \
# 0  Britney Spears  Oops!...I Did It Again       211160  2000          77
# 1       blink-182    All The Small Things       167066  1999          79
# 2      Faith Hill                 Breathe       250546  1999          66
# 3        Bon Jovi            It's My Life       224493  2000          78
# 4          *NSYNC             Bye Bye Bye       200560  2000          65
#
#    danceability  energy  loudness  speechiness  acousticness  liveness  \
# 0         0.751   0.834    -5.444       0.0437        0.3000    0.3550
# 1         0.434   0.897    -4.918       0.0488        0.0103    0.6120
# 2         0.529   0.496    -9.007       0.0290        0.1730    0.2510
# 3         0.551   0.913    -4.063       0.0466        0.0263    0.3470
# 4         0.614   0.928    -4.806       0.0516        0.0408    0.0845
#
#    valence    tempo         genre
# 0    0.894   95.053           pop
# ...

# %%
#Şarkı sürelerini ms den s ye çeviriyoruz

df5['duration_ms'] = df5['duration_ms']/1000
df5['duration_ms'] = df5['duration_ms'].astype(int)
df5.head()
# Out:
#            artist                    song  duration_ms  year  popularity  \
# 0  Britney Spears  Oops!...I Did It Again          211  2000          77
# 1       blink-182    All The Small Things          167  1999          79
# 2      Faith Hill                 Breathe          250  1999          66
# 3        Bon Jovi            It's My Life          224  2000          78
# 4          *NSYNC             Bye Bye Bye          200  2000          65
#
#    danceability  energy  loudness  speechiness  acousticness  liveness  \
# 0         0.751   0.834    -5.444       0.0437        0.3000    0.3550
# 1         0.434   0.897    -4.918       0.0488        0.0103    0.6120
# 2         0.529   0.496    -9.007       0.0290        0.1730    0.2510
# 3         0.551   0.913    -4.063       0.0466        0.0263    0.3470
# 4         0.614   0.928    -4.806       0.0516        0.0408    0.0845
#
#    valence    tempo         genre
# 0    0.894   95.053           pop
# ...

# %%
df5.rename(columns={'duration_ms': 'Şarkı süresi(s)'}, inplace=True)
df5.head()
# Out:
#            artist                    song  Şarkı süresi(s)  year  popularity  \
# 0  Britney Spears  Oops!...I Did It Again              211  2000          77
# 1       blink-182    All The Small Things              167  1999          79
# 2      Faith Hill                 Breathe              250  1999          66
# 3        Bon Jovi            It's My Life              224  2000          78
# 4          *NSYNC             Bye Bye Bye              200  2000          65
#
#    danceability  energy  loudness  speechiness  acousticness  liveness  \
# 0         0.751   0.834    -5.444       0.0437        0.3000    0.3550
# 1         0.434   0.897    -4.918       0.0488        0.0103    0.6120
# 2         0.529   0.496    -9.007       0.0290        0.1730    0.2510
# 3         0.551   0.913    -4.063       0.0466        0.0263    0.3470
# 4         0.614   0.928    -4.806       0.0516        0.0408    0.0845
#
#    valence    tempo         genre
# 0    0.894   95.053           pop
# ...

# %%
dfc = df5.drop("acousticness", axis=1)
print(df.shape)
dfc.head()
# Out:
# (2000, 18)
#            artist                    song  Şarkı süresi(s)  year  popularity  \
# 0  Britney Spears  Oops!...I Did It Again              211  2000          77
# 1       blink-182    All The Small Things              167  1999          79
# 2      Faith Hill                 Breathe              250  1999          66
# 3        Bon Jovi            It's My Life              224  2000          78
# 4          *NSYNC             Bye Bye Bye              200  2000          65
#
#    danceability  energy  loudness  speechiness  liveness  valence    tempo  \
# 0         0.751   0.834    -5.444       0.0437    0.3550    0.894   95.053
# 1         0.434   0.897    -4.918       0.0488    0.6120    0.684  148.726
# 2         0.529   0.496    -9.007       0.0290    0.2510    0.278  136.859
# 3         0.551   0.913    -4.063       0.0466    0.3470    0.544  119.992
# 4         0.614   0.928    -4.806       0.0516    0.0845    0.879  172.656
#
#           genre
# 0           pop
# ...

# %%
#Sutun adını buyuk harf yapıyoruz(hocam yapacak bişe kalmadı)

olumns = dfc.columns

new_columns = [column.capitalize() for column in columns]

dfc.columns = new_columns

print(dfc.head())
# Out:
#            Artist                    Song  Şarkı süresi(s)  Year  Popularity  \
# 0  Britney Spears  Oops!...I Did It Again              211  2000          77
# 1       blink-182    All The Small Things              167  1999          79
# 2      Faith Hill                 Breathe              250  1999          66
# 3        Bon Jovi            It's My Life              224  2000          78
# 4          *NSYNC             Bye Bye Bye              200  2000          65
#
#    Danceability  Energy  Loudness  Speechiness  Liveness  Valence    Tempo  \
# 0         0.751   0.834    -5.444       0.0437    0.3550    0.894   95.053
# 1         0.434   0.897    -4.918       0.0488    0.6120    0.684  148.726
# 2         0.529   0.496    -9.007       0.0290    0.2510    0.278  136.859
# 3         0.551   0.913    -4.063       0.0466    0.3470    0.544  119.992
# 4         0.614   0.928    -4.806       0.0516    0.0845    0.879  172.656
#
#           Genre
# 0           pop
# 1     rock, pop
# ...

# %%
#Artık analiz yapabiliriz
#2000 yılında çıkan ve Temposu 100den büyük olan şarkılar

filtered_dfc = dfc.loc[(dfc['Year'] == 2000) & (dfc['Tempo'] > 100), 'Song']
print(filtered_dfc)
# Out:
# 3                       It's My Life
# 4                        Bye Bye Bye
# 6                The Real Slim Shady
# 7                            Rock DJ
# 12                        Freestyler
# 17                  Better Off Alone
# 20                        In the End
# 22                  It Feels So Good
# 25                Take A Look Around
# 28                   The Time Is Now
# 31                     Dance with Me
# 32                             Music
# 36                   Spinning Around
# 39                         Separated
# 48             Shackles (Praise You)
# 51       She Bangs - English Version
# 52                   He Can't Love U
# 56              Who Let The Dogs Out
# 63                        Fill Me In
# 65                      American Pie
# 67                         I Like It
# 70               Don't Think I'm Not
# 71                      There You Go
# 72                      Shalala Lala
# 73           Life Is A Rollercoaster
# ...

# %%
songs = dfc.loc[(dfc['Year'] == 2013) | (dfc['Valence'] <= 0.5), 'Song']
print(songs)
# Out:
# 2                                      Breathe
# 13                                 Desert Rose
# 14                     Never Be The Same Again
# 19                            The Next Episode
# 20                                  In the End
#                          ...
# 1987                                 gone girl
# 1989                           One Thing Right
# 1990                         How Do You Sleep?
# 1994               Goodbyes (Feat. Young Thug)
# 1998    Dancing With A Stranger (with Normani)
# Name: Song, Length: 856, dtype: object

# %%
#Yıllara göre çıkan şarkıları plot halinde yazıyoruz
# Her yılın toplam şarkı sayısını hesaplıyoruz
songs_per_year = dfc['Year'].value_counts().sort_index()

# Grafik çizimi
plt.figure(figsize=(10, 6))
plt.plot(songs_per_year.index, songs_per_year.values, marker='o', color='skyblue', linestyle='-')
plt.xlabel('Yıl')
plt.ylabel('Şarkı Sayısı')
plt.title('Yıllara Göre Çıkan Şarkı Sayısı')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
